# %% [markdown]
# # Configuration Check
#
# This notebook verifies that environment variables are properly loaded from the `.env` file.
#
# ## What's being checked:
# - Database configuration (DB_NAME, DB_HOST, etc.)
# - API keys (OpenAI, Anthropic, Groq, etc.)
# - Other environment settings
#
# Run the cell below to verify your configuration is loaded correctly.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

#print(os.getenv("OPENAI_API_KEY"))
print(os.getenv("DB_NAME"))
# Out:
# AdventureWorks
