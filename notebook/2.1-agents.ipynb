# %%
from langchain_ollama import ChatOllama
from langchain_openai import ChatOpenAI
from langchain.tools import tool
from langchain.agents import create_agent

@tool
def get_weather(city: str) -> str:
    """Get current weather for a city."""
    return f"Weather in {city}: 72°F, sunny"

ollamaLLM = ChatOllama(model="llama3-groq-tool-use")
gptLLM = ChatOpenAI(model_name="gpt-4",temperature=0)

agent = create_agent(
    model=gptLLM,
    tools=[get_weather],
    system_prompt="You are a helpful assistant with weather tools."
)

result = agent.invoke({
    "messages": [{"role": "user", "content": "My Name is Ron. What's the weather like in New York City?"}]
})
print(result["messages"][-1].content)

result = agent.invoke({
    "messages": [{"role": "user", "content": "What is my Name"}]
})
print(result["messages"][-1].content)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from langchain.agents import create_agent
#       2 from langchain_ollama import ChatOllama
#       3 from langchain_openai import ChatOpenAI
#
# ImportError: cannot import name 'create_agent' from 'langchain.agents' (c:\Users\sourabh.gupta\.virtualenvs\Demo-oRXnH7h7\lib\site-packages\langchain\agents\__init__.py)

# %%
from langchain_core.messages import HumanMessage, AIMessage
# Conversation state (persists across turns)
messages = []

# Turn 1
result1 = agent.invoke({"messages": messages + [HumanMessage(content="My Name is Ron. What's the weather like in New York City?")]})
messages.extend(result1["messages"])  # Add agent response to history
print(result1["messages"][-1].content)

# Turn 2 - agent remembers previous context!
result2 = agent.invoke({"messages": messages + [HumanMessage(content="What is my Name?")]})
messages.extend(result2["messages"])
print(result2["messages"][-1].content)

# %%
def chat_with_agent(agent, max_turns=10):
    """Full chat loop with automatic memory management"""
    messages = []
    
    print("SQL Agent ready! Type 'quit' to exit.")
    
    for turn in range(max_turns):
        user_input = input("\nYou: ")
        if user_input.lower() == 'quit':
            break
            
        # Append user message to history + send to agent
        input_messages = messages + [HumanMessage(content=user_input)]
        result = agent.invoke({"messages": input_messages})
        
        # Update conversation history
        messages.extend(result["messages"])
        
        # Print only the latest assistant response
        print(f"\nAgent: {result['messages'][-1].content}")

# Usage
chat_with_agent(agent)
